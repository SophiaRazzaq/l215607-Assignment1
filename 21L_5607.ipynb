# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here

def function(a, n, m):
    if n != m:
      return False
    isPresent = [[False for i in range(n)] 
                        for j in range(m)]
  
    for i in range(n):
        for j in range(m):

            if not isinstance(a[i][j], int):
              return False
            for k in range(n):
                if i != k and a[i][j] == a[k][j]:
                    isPresent[i][j] = True
                    isPresent[k][j] = True
            for k in range(m):
                if j != k and a[i][j] == a[i][k]:
                    isPresent[i][j] = True
                    isPresent[i][k] = True
    for i in range(n):
        for j in range(m):
                if not isPresent[i][j]:
                  continue
                else:
                  return False
    return True
#driver code
#test any value
#n=num of rows
#m=num of cols
#a=the array
n=4
m=4

a = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]
#checker function
flag = function(a, n, m)
print(flag)
# Out:
# False

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
from google.colab import files
 
 
uploaded = files.upload()



import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['StudentMarkSheet.csv']))
print(df)
# Out:
#      <input type="file" id="files-dbea83a1-a80b-4bf6-883f-1676362424b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbea83a1-a80b-4bf6-883f-1676362424b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
len(df.index)
df = df.dropna(how='any',axis=0)
print(df)
len(df.index)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [196 rows x 4 columns]
# 196

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
#df.iloc[0]
df.loc[df['Student name']=='James Walker', :]
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#choose all the cells named "biology" from exam row and take the mean of values
avgb=df.loc[df['Exam name']=='Biology', :].mean()
print("AVERAGE FOR BIOLOGY")
print(avgb)

avgc=df.loc[df['Exam name']=='Chemistry', :].mean()
print("AVERAGE FOR CHEMISTRY")
print(avgc)

avgm=df.loc[df['Exam name']=='Mathematics', :].mean()
print("AVERAGE FOR MATHEMATICS")
print(avgm)


avgp=df.loc[df['Exam name']=='Philosophy', :].mean()
print("AVERAGE FOR PHILOSOPHY")
print(avgp)


avgpy=df.loc[df['Exam name']=='Physics', :].mean()
print("AVERAGE FOR PHYSICS")
print(avgpy)


avgs=df.loc[df['Exam name']=='Sociology', :].mean()
print("AVERAGE FOR SOIOLOGY")
print(avgs)
# Out:
# AVERAGE FOR BIOLOGY
# Marks    47.894737
# dtype: float64
# AVERAGE FOR CHEMISTRY
# Marks    50.576923
# dtype: float64
# AVERAGE FOR MATHEMATICS
# Marks    48.972222
# dtype: float64
# AVERAGE FOR PHILOSOPHY
# Marks    47.27027
# dtype: float64
# AVERAGE FOR PHYSICS
# Marks    51.761905
# dtype: float64
# AVERAGE FOR SOIOLOGY
# Marks    56.026316
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#x=np.array([""])
#plt.bar()
x=np.array(["Biology"," Chemistry"," Mathematics"," Philosophy"," Physics"," Sociology"])
y=np.array([47.89,50.57,48.97,47.27,51.76,56.02])
plt.bar(x,y,color=(0.1, 0.1, 0.1, 0.1),  edgecolor='pink')
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
from google.colab import files
 
 
uploaded = files.upload()



import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['CatData.csv']))
print(df)

len(df.index)
df = df.dropna(how='any',axis=0)
print(df)
len(df.index)
# Out:
#      <input type="file" id="files-1108f8c0-5a34-47e7-b26e-70aa8e9ddd2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1108f8c0-5a34-47e7-b26e-70aa8e9ddd2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: 

Y = df.iloc[:, -1].values
print(Y)
# independant variable: 

X = df.iloc[:, :-1].values
print(X)
# Out:
# [3.75  3.8   3.25  3.45  3.65  3.625 4.675 3.475 4.25  3.3   3.7   3.2
#  3.8   4.4   3.7   3.45  4.5   3.325 4.2   3.4   3.6   3.8   3.95  3.8
#  3.8   3.55  3.2   3.15  3.95  3.25  3.9   3.3   3.9   3.325 4.15  3.95
#  3.55  3.3   4.65  3.15  3.9   3.1   4.4   3.    4.6   3.425 2.975 3.45
#  4.15  3.5   4.3   3.45  4.05  2.9   3.7   3.55  3.8   2.85  3.75  3.15
#  4.4   3.6   4.05  2.85  3.95  3.35  4.1   3.05  4.45  3.6   3.9   3.55
#  4.15  3.7   4.25  3.7   3.9   3.55  4.    3.2   4.7   3.8   4.2   3.35
#  3.55  3.8   3.5   3.95  3.6   3.55  4.3   3.4   4.45  3.3   4.3   3.7
#  4.35  2.9   4.1   3.725 4.725 3.075 4.25  2.925 3.55  3.75  3.9   3.175
#  4.775 3.825 4.6   3.2   4.275 3.9   4.075 2.9   3.775 3.35  3.325 3.15
#  3.5   3.45  3.875 3.05  4.    3.275 4.3   3.05  4.    3.325 3.5   3.5
#  4.475 3.425 3.9   3.175 3.975 3.4   4.25  3.4   3.475 3.05  3.725 3.
#  3.65  4.25  3.475 3.45  3.75  3.7   4.    4.5   5.7   4.45  5.7   5.4
# ...

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


df=df[["Tail Length (cm)", "Mass (kg)"]]
print(df.head())


plt.scatter(df["Tail Length (cm)"],df["Mass (kg)"])
plt.title("Tail Length (cm) vs Mass (kg)")
plt.xlabel("Tail Length (cm)")
plt.ylabel("Mass (kg)")
plt.show()
# Out:
#    Tail Length (cm)  Mass (kg)
# 0              18.1       3.75
# 1              18.6       3.80
# 2              19.5       3.25
# 3              19.3       3.45
# 4              19.0       3.65

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from scipy import stats
import scipy
df = pd.read_csv("CatData.csv", header=0, sep=",")

x = df["Tail Length (cm)"]
y = df["Mass (kg)"]
slope_intercept = np.polyfit(x,y,1)
print("\nSLOPE IS GIVEN")
print(slope_intercept)


#REAL

def simple_linear_regression(df,i,o):
  xi=i
  yi=o
#total num of data points
  n=len(xi)


#mean or bar value of x n y
  xi_m=xi.mean()

  yi_m=yi.mean()

#sum of the values
  sx=(xi).sum()

  sy=(yi).sum()

#sum of x*y multiplied by n
  sxy=((xi*yi).sum())*n

#sum of x*sum of y
  s_x_y=sx*sy


#sum of x*x multiplies by n
  sxxi=((xi*xi).sum())*n

#sq of sum of x
  sxisq=sx*sx
#slope
  slope=(sxy-s_x_y)/(sxxi-sxisq)
 #intercept
  inter=yi_m-slope*xi_m

#print("FOLLOWING IS THE SLOPE")
 #print(slope)
 #print("FOLLOWING IS THE Y-INTERCEPT")
 #print(intercept)
# Out:
# SLOPE IS GIVEN
# [ 0.49685566 -5.78083136]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
df.plot.scatter(x='Tail Length (cm)', y='Mass (kg)',color='pink')

m, b = np.polyfit(df["Tail Length (cm)"],df["Mass (kg)"],1)
plt.plot(x, m*x+b)
